# %%
#First Order Linear Ordinary D.E
import math

# %%
#rabbit reproduction

# %%
k = int(input("Initial rabbit amount : "))
ramda = float(input("rate of reproductino : "))
t = int(input("generation : "))

for i in range(t) :
    print(f"DAY {i+1}", k)
    k = int(k * math.e**ramda)      # x_dot = dx/dt = e^(ramda*t) * x_0
# Out:
# DAY 1 10
# DAY 2 73
# DAY 3 539
# DAY 4 3982
# DAY 5 29423
